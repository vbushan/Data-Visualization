# %% [markdown]
# # Visual Design Assignment

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Numpy for Numerical Computation

# %% [markdown]
# Using numpy linspace function to generate 50 eually distant points in a given range-

# %%
np.linspace(0, 3)
# Out:
# array([0.        , 0.06122449, 0.12244898, 0.18367347, 0.24489796,
#        0.30612245, 0.36734694, 0.42857143, 0.48979592, 0.55102041,
#        0.6122449 , 0.67346939, 0.73469388, 0.79591837, 0.85714286,
#        0.91836735, 0.97959184, 1.04081633, 1.10204082, 1.16326531,
#        1.2244898 , 1.28571429, 1.34693878, 1.40816327, 1.46938776,
#        1.53061224, 1.59183673, 1.65306122, 1.71428571, 1.7755102 ,
#        1.83673469, 1.89795918, 1.95918367, 2.02040816, 2.08163265,
#        2.14285714, 2.20408163, 2.26530612, 2.32653061, 2.3877551 ,
#        2.44897959, 2.51020408, 2.57142857, 2.63265306, 2.69387755,
#        2.75510204, 2.81632653, 2.87755102, 2.93877551, 3.        ])

# %% [markdown]
# The linspace functions by defualt chooses to generate 50 points. We can define the number of arguments we require as a third argument to this function.

# %%
np.linspace(0, 3, 10)     # 10 numbers instead of 50
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        , 1.33333333,
#        1.66666667, 2.        , 2.33333333, 2.66666667, 3.        ])

# %% [markdown]
# Numpy is a popular package in python for numerical computions. It is simple and loaded with features which enable us to do numerical computation easily. For example, To generate the sin of values in a range we can use the following code-

# %%
np.sin(np.linspace(0,7))
# Out:
# array([ 0.        ,  0.14237173,  0.28184285,  0.41557185,  0.54083421,
#         0.6550779 ,  0.75597537,  0.84147098,  0.90982291,  0.95963858,
#         0.98990308,  0.9999998 ,  0.98972305,  0.9592822 ,  0.90929743,
#         0.84078711,  0.75514703,  0.65412197,  0.53977018,  0.41442139,
#         0.2806294 ,  0.14112001, -0.00126449, -0.14362322, -0.28305585,
#        -0.41672165, -0.54189738, -0.65603277, -0.7568025 , -0.84215352,
#        -0.91034694, -0.95999344, -0.99008152, -0.9999982 , -0.98954144,
#        -0.95892427, -0.90877049, -0.84010188, -0.75431748, -0.65316501,
#        -0.53870529, -0.41327027, -0.2794155 , -0.13986806,  0.00252898,
#         0.14487449,  0.2842684 ,  0.41787078,  0.54295968,  0.6569866 ])

# %% [markdown]
# # Task 1: Plot sin and cos functions

# %%
x=np.linspace(0,10)
sin_x=np.sin(x)
cos_x=np.cos(x)

plt.plot(x,sin_x,label='sin');
plt.plot(x,cos_x,label='cos');

plt.legend();

# %% [markdown]
# To access a colormap for plotting, we can use the following code:

# %%
plt.plot(x, np.sin(x), color=plt.cm.Pastel1(0));
plt.plot(x, np.cos(x), color=plt.cm.Pastel1(1));

# %% [markdown]
# To see the different colors in a color map, we can use the following code-

# %%
plt.cm.Pastel1.colors
# Out:
# ((0.984313725490196, 0.7058823529411765, 0.6823529411764706),
#  (0.7019607843137254, 0.803921568627451, 0.8901960784313725),
#  (0.8, 0.9215686274509803, 0.7725490196078432),
#  (0.8705882352941177, 0.796078431372549, 0.8941176470588236),
#  (0.996078431372549, 0.8509803921568627, 0.6509803921568628),
#  (1.0, 1.0, 0.8),
#  (0.8980392156862745, 0.8470588235294118, 0.7411764705882353),
#  (0.9921568627450981, 0.8549019607843137, 0.9254901960784314),
#  (0.9490196078431372, 0.9490196078431372, 0.9490196078431372))

# %% [markdown]
# # Task 2. Pick a qualitative colormap and draw four different curves with four different colors.

# %%
#figure
fig, ax1 = plt.subplots()
fig.set_size_inches(14, 7)

x = np.linspace(0,10,150) 
plt.plot(x,np.sin(x),color=plt.cm.Paired.colors[1],label="sin(x)");
plt.plot(x,np.sin(-x),color=plt.cm.Paired.colors[-1],label="sin(-x)");
plt.plot(x,np.cos(x),color=plt.cm.Paired.colors[5],label="cos(x)");
plt.plot(x,np.cos(2*x),color=plt.cm.Paired.colors[6],label="cos(2x)");
plt.legend();

# %%
#figure
fig, ax1 = plt.subplots()
fig.set_size_inches(14, 7)

x = np.linspace(0,10,150) 
plt.plot(x,np.sin(x),color=plt.cm.tab20.colors[0],label="sin(x)");
plt.plot(x,np.sin(-x),color=plt.cm.tab20.colors[2],label="sin(-x)");
plt.plot(x,np.cos(x),color=plt.cm.tab20.colors[-4],label="cos(x)");
plt.plot(x,np.cos(2*x),color=plt.cm.tab20.colors[-6],label="cos(2x)");
plt.legend();

# %% [markdown]
# # Quantitative colormaps

# %% [markdown]
# Quantiative colormaps are used to represent information that has order.

# %%
from collections import OrderedDict # import a specialized container datatype - ordered dictionary

cmaps = OrderedDict()

cmaps['Perceptually Uniform Sequential'] = [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']

cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

cmaps['Sequential (2)'] = [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']

cmaps['Diverging'] = [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']

cmaps['Cyclic'] = ['twilight', 'twilight_shifted', 'hsv']

cmaps['Qualitative'] = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']

cmaps['Miscellaneous'] = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar']

nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps.items())
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()

for cmap_category, cmap_list in cmaps.items():
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %% [markdown]
# # Task 3: Try out different colormaps.

# %%
import pandas as pd
import matplotlib.pyplot as plt

#import data and create dataframe
wine_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data' 
wine_column_headers = ['Alcohol','Malic acid','Ash','Alcalinity of ash',  
                       'Magnesium','Total phenols','Flavanoids',
                       'Nonflavanoid phenols','Proanthocyanins','Color intensity', 
                       'Hue','OD280/OD315 of diluted wines' ,'Proline']
wine_df = pd.read_csv(wine_url, names = wine_column_headers)

#figure
fig, ax1 = plt.subplots()
fig.set_size_inches(13, 10)

#labels
ax1.set_xlabel('Alcohol')
ax1.set_ylabel('Color Intensity')
ax1.set_title('Relationship Between Color Intensity and Alcohol Content in Wines')

#c sequence
c = wine_df['Color intensity']

#plot
plt.scatter( wine_df['Alcohol'], wine_df['Color intensity'] , c=c, 
            cmap = 'RdPu', s = wine_df['Proline']*.5, alpha =0.5)
cbar = plt.colorbar()
cbar.set_label('Color Intensity')

# %%
#figure
fig, ax1 = plt.subplots()
fig.set_size_inches(13, 10)

#labels
ax1.set_xlabel('Color Intensity')
ax1.set_ylabel('Hue')
ax1.set_title('Relationship Between Hue and Color Intensity in Wines')

#c sequence
c = wine_df['Hue']

#plot
plt.scatter( wine_df['Color intensity'], wine_df['Hue'] , c=c, 
            cmap = 'RdPu', s = wine_df['Proline']*.5, alpha =0.5)
cbar = plt.colorbar()
cbar.set_label('Hue')

# %%
#figure
fig, ax1 = plt.subplots()
fig.set_size_inches(13, 10)

#labels
ax1.set_xlabel('Alcohol')
ax1.set_ylabel('Hue')
ax1.set_title('Relationship Between Hue and Alcohol Content in Wines')

#c sequence
c = wine_df['Hue']

#plot
plt.scatter( wine_df['Alcohol'], wine_df['Hue'] , c=c, 
            cmap = 'Spectral', s = wine_df['Proline']*.5, alpha =0.5)
cbar = plt.colorbar()
cbar.set_label('Hue')

# %% [markdown]
# # Interpret your results.

# %% [markdown]
# 1) Task 1: In this task, I used the numpy library and matplot.pyplot module library to plot the cos and sine trignometric functions. I don't explicitly choose the colors of each plot, instead matplotlib picked a good color pair by default. Orange-blue pair is colorblind-safe, it is opposite on the color wheel, and this pair produces the strongest contrast while at the same time reinforcing each other.
#
# 2) Task 2: For this I plotted for trignometric functions sin(x), sin(2x), cos(x), cos(2x). I chose the tab20 color map to create the plots for each function. The tab20 color map offers a wide range of colors, so it's easy to chose different colors for each plot as the plots are unrelated. I tried to balance the colors is each plot by choosing the set either ends of the color wheel. I also ensured to avoid shades of red with green. To improve, I could probably choose colors from different color maps for each plot.
#
# 3) Task 3: In this task, I plotted three scatter plots. The first plot indicates the relationship between Alchol content and color intesity. For this plot, I chose the "RdPu" color map, as the colors are relevant with wine colors. The plot shows are clear trend in color intensity with increase in Alcohol content. The second plot indicates the replationship between Hue and color intensity. Here, I chose the same color map as the previous plot. The plot indicates a downward trend in Hue with color intensity. The third plot indicates a relationship between Hue and Alcohol content. I chose the spectral cmap for this plot. I added a color bar with each of the scatter plot to indicate the intensity level. The obvious problem with the plots is the size of the circles. To make the visualization look good, I chose the wine proline column in the data frame. This dimension in not obvious to the reader unless specified. This could either be attributed well in the plot or in the explanation of the plot.
